# %% [markdown]
# ### **Bike Price Prediction using Linear Regression**

# %% [markdown]
# **Import Library**

# %%
import pandas as pd

# %%
import numpy as np

# %% [markdown]
# **Import CSV as DataFrame**

# %%
df = pd.read_csv(r'https://github.com/YBI-Foundation/Dataset/raw/main/Bike%20Prices.csv')

# %% [markdown]
# **Get the First Five Rows of DataFrame**

# %%
df.head()
# Out:
#    Brand               Model  Selling_Price  Year Seller_Type      Owner  \
# 0    TVS          TVS XL 100          30000  2017  Individual  1st owner
# 1  Bajaj       Bajaj  ct 100          18000  2017  Individual  1st owner
# 2     Yo            Yo Style          20000  2011  Individual  1st owner
# 3  Bajaj  Bajaj Discover 100          25000  2010  Individual  1st owner
# 4  Bajaj  Bajaj Discover 100          24999  2012  Individual  2nd owner
#
#    KM_Driven  Ex_Showroom_Price
# 0       8000            30490.0
# 1      35000            32000.0
# 2      10000            37675.0
# 3      43000            42859.0
# 4      35000            42859.0

# %% [markdown]
# **Get Information of DataFrame**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1061 entries, 0 to 1060
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Brand              1061 non-null   object
#  1   Model              1061 non-null   object
#  2   Selling_Price      1061 non-null   int64
#  3   Year               1061 non-null   int64
#  4   Seller_Type        1061 non-null   object
#  5   Owner              1061 non-null   object
#  6   KM_Driven          1061 non-null   int64
#  7   Ex_Showroom_Price  626 non-null    float64
# dtypes: float64(1), int64(3), object(4)
# memory usage: 66.4+ KB

# %% [markdown]
# **Get Missing Values Drop**

# %%
df = df.dropna()

# %% [markdown]
# **Get Summary Statistics**

# %%
df.describe()
# Out:
#        Selling_Price         Year      KM_Driven  Ex_Showroom_Price
# count     626.000000   626.000000     626.000000       6.260000e+02
# mean    59445.164537  2014.800319   32671.576677       8.795871e+04
# std     59904.350888     3.018885   45479.661039       7.749659e+04
# min      6000.000000  2001.000000     380.000000       3.049000e+04
# 25%     30000.000000  2013.000000   13031.250000       5.485200e+04
# 50%     45000.000000  2015.000000   25000.000000       7.275250e+04
# 75%     65000.000000  2017.000000   40000.000000       8.703150e+04
# max    760000.000000  2020.000000  585659.000000       1.278000e+06

# %% [markdown]
# **Get Categories and Counts of Categorical Variables**

# %%
df[['Brand']].value_counts()
# Out:
# Brand
# Honda       170
# Bajaj       143
# Hero        108
# Yamaha       94
# Royal        40
# TVS          23
# Suzuki       18
# KTM           6
# Mahindra      6
# Kawasaki      4
# UM            3
# Activa        3
# Harley        2
# Vespa         2
# BMW           1
# Hyosung       1
# Benelli       1
# Yo            1
# dtype: int64

# %%
df[['Model']].value_counts()
# Out:
# Model
# Honda Activa [2000-2015]                      23
# Honda CB Hornet 160R                          22
# Bajaj Pulsar 180                              20
# Yamaha FZ S V 2.0                             16
# Bajaj Discover 125                            16
#                                               ..
# Royal Enfield Thunderbird 500                  1
# Royal Enfield Continental GT [2013 - 2018]     1
# Royal Enfield Classic Stealth Black            1
# Royal Enfield Classic Squadron Blue            1
# Yo Style                                       1
# Length: 183, dtype: int64

# %%
df[['Seller_Type']].value_counts()
# Out:
# Seller_Type
# Individual     623
# Dealer           3
# dtype: int64

# %%
df[['Owner']].value_counts()
# Out:
# Owner
# 1st owner    556
# 2nd owner     66
# 3rd owner      3
# 4th owner      1
# dtype: int64

# %% [markdown]
# **Get Column Names**

# %%
df.columns
# Out:
# Index(['Brand', 'Model', 'Selling_Price', 'Year', 'Seller_Type', 'Owner',
#        'KM_Driven', 'Ex_Showroom_Price'],
#       dtype='object')

# %% [markdown]
# **Get Shape of DataFrame**

# %%
df.shape
# Out:
# (626, 8)

# %% [markdown]
# **Get Encoding of Categorical Features**

# %%
df.replace({'Seller_Type':{'Individual':0,'Dealer':1}},inplace=True)

# %%
df.replace({'Owner':{'1st owner':0, '2nd owner':1,'3rd owner':2,'4th owner':3}},inplace=True)

# %% [markdown]
# **Define y(dependent or label or target varaible) and X(independent or features or attribute Variable)**

# %%
y=df['Selling_Price']

# %%
y.shape
# Out:
# (626,)

# %%
y
# Out:
# 0       30000
# 1       18000
# 2       20000
# 3       25000
# 4       24999
#         ...
# 621    330000
# 622    300000
# 623    425000
# 624    760000
# 625    750000
# Name: Selling_Price, Length: 626, dtype: int64

# %%
X=df[['Year','Seller_Type', 'Owner', 'KM_Driven', 'Ex_Showroom_Price']]

# %%
X.shape
# Out:
# (626, 5)

# %%
X
# Out:
#      Year  Seller_Type  Owner  KM_Driven  Ex_Showroom_Price
# 0    2017            0      0       8000            30490.0
# 1    2017            0      0      35000            32000.0
# 2    2011            0      0      10000            37675.0
# 3    2010            0      0      43000            42859.0
# 4    2012            0      1      35000            42859.0
# ..    ...          ...    ...        ...                ...
# 621  2014            0      3       6500           534000.0
# 622  2011            0      0      12000           589000.0
# 623  2017            0      1      13600           599000.0
# 624  2019            0      0       2800           752020.0
# 625  2013            0      1      12000          1278000.0
#
# [626 rows x 5 columns]

# %% [markdown]
# **Get Train Test Split**

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test, y_train,y_test = train_test_split(X,y,test_size =0.3, random_state =222529)

# %%
X_train.shape,X_test.shape,y_train.shape,y_test.shape
# Out:
# ((438, 5), (188, 5), (438,), (188,))

# %% [markdown]
# **Get Model Train**

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# **Get Model Prediction**

# %%
y_pred = lr.predict(X_test)

# %%
y_pred.shape
# Out:
# (188,)

# %%
y_pred
# Out:
# array([ 44403.8278319 ,  53465.72360978, 112688.63446378,  43378.4313757 ,
#         69153.65615935, 126815.11567119,  48628.54851828,  92065.98925885,
#         35330.62306616,  41046.33394617,  79189.18118734,  31329.35114115,
#         73634.9727654 ,  78393.64792988,  84428.36482518,  62631.6748448 ,
#         56478.97328515,  54224.42118254,  60038.26395886,  96349.2884337 ,
#         42578.81822002, -11991.83908669, 131764.79070423,  62775.79841448,
#         60188.18047099,  96716.38469481,  75656.89787167,  41349.75211548,
#        108454.28568652,   6049.14974833,  40171.735659  ,  44109.43555983,
#         56240.65159249,  25482.48825158,  61431.77064475,  61735.52088111,
#         88894.30874296,  42402.37291707,  66720.31662172,  58255.33256407,
#         -1497.47020804,  22847.86558058,  51442.93678671,  53801.00794925,
#         15637.55559431,  39924.55570657,  44916.52493715,  39966.8970299 ,
#         54397.0281732 , 107082.01077164,  61822.67663797,  48944.46413316,
#         24865.0215997 ,  44961.56584496,  24817.33199161,  39543.48379661,
#         50532.18521761,  39905.65637637,  63835.12448967,  79959.13093506,
#         18133.57926938,  49882.95159323,  56818.59172248,  75347.04775647,
#         78033.30066584,  25598.28053925,  -2438.7907292 ,  55921.03904197,
#        151646.2807483 ,  60122.94660551,  36623.81832441,  26972.05241391,
#         12344.95877858,  20410.66974636,  50326.63300143,  50337.71997242,
#        112863.25008119,  39520.83566789,  26012.10361833,  79134.59885504,
#         98463.24275192,  40461.65570763,  -7800.95116062,  25994.90856201,
#         60617.33679658,  52162.7392833 ,  21929.81616134,  76238.31765004,
#         34701.75104882,  69855.26142045,   5788.68068598,  47417.98461788,
#         46047.81996994,  53517.90472129,  24213.47584509, 385370.38189266,
#        122561.28122577,  84052.8742792 ,  58324.92440138, -13542.6792459 ,
#         34226.63452534,  79684.49017195,  27955.58311466,  31405.72084989,
#         31507.43123502,  65168.56460661, 122421.4082499 , 116784.28944964,
#         64945.85839563,  21901.0350141 , 128470.25025607,  43226.29761983,
#         59713.53626606,  51431.65159859,  88951.13589473,  27323.40060963,
#         33004.31529586,  22838.67167085,  47358.22095881,  52947.58753924,
#         25202.09686627,  52540.79034777,  60687.49573431,  39035.38791665,
#        -27935.20023424,  59657.08116829,  92068.81201374,  55228.39550068,
#         43702.71584774,  37204.30149864,  31851.20716835,  74255.23196715,
#         59089.53448811,  27511.22510944,  89227.99718743,  51311.52594279,
#         -9010.51120931,  55748.62374597,  32300.4577764 ,  27430.35434874,
#         44648.67107558,  56733.90907582,  17432.17526386,  44228.36615933,
#         59733.29291544,  45882.6136532 ,  16970.27772649,  62037.89379415,
#         25032.73157295,  39464.68544387, 139225.93140785,  72596.69506304,
#         41154.84581475, 125528.47852739,  73246.16379379,  38950.70527   ,
#         60380.11258159,  53576.12968901,  45632.16545826,  42294.78850658,
#         62965.97023529, 113702.72444482, 106947.90768133,  39543.48379661,
#         65536.85147016,  42429.6932469 , 119003.74558457,  14056.27713893,
#         54719.42714233,  22558.5815764 ,  32231.18333463,  37767.35421876,
#        496662.68540957,  34071.92999171,  62511.39222316, 136434.22243238,
#         29795.25220915,  34870.75894227,  59514.11138355,  33322.97599648,
#         23496.57945739,  25731.8424368 ,  35864.67591187, 133167.50757257,
#         53723.75620119,  20421.20192947,  53889.81717725,  52609.5962725 ])

# %% [markdown]
# **Get Model Evaluation**

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 628772712.5339837

# %%
mean_absolute_error(y_test,y_pred)
# Out:
# 12628.985929030261

# %%
r2_score(y_test, y_pred)
# Out:
# 0.8670818449563504

# %% [markdown]
# **Get Visualization of Actual Vs Predicted Results**

# %%
import matplotlib.pyplot as plt
plt.scatter(y_test,y_pred)
plt.xlabel('Actual Prices')
plt.ylabel('Predicted Prices')
plt.title('Actual Price vs Predicted Price')
plt.show()

# %% [markdown]
# **Get Future Predictions**

# %%
df_new = df.sample(1)

# %%
df_new
# Out:
#      Brand               Model  Selling_Price  Year  Seller_Type  Owner  \
# 123  Bajaj  Bajaj Discover 150          30000  2011            0      1
#
#      KM_Driven  Ex_Showroom_Price
# 123      39500            54299.0

# %%
df_new.shape
# Out:
# (1, 8)

# %%
X_new = df_new.drop(['Brand', 'Model', 'Selling_Price'],axis = 1)

# %%
y_pred_new = lr.predict(X_new)

# %%
y_pred_new
# Out:
# array([14243.47961298])
